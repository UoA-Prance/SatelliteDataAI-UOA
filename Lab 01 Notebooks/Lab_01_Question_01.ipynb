# %% [markdown]
# # Setup

# %%
# Set up GEE API
import ee
ee.Authenticate()
ee.Initialize(project='geog-761-610050525')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Set up GEE API
# ----> 2 import ee
#       3 ee.Authenticate()
#       4 ee.Initialize(project='geog-761-610050525')
#
# ModuleNotFoundError: No module named 'ee'

# %%
# Install the geemap package (only needs to be run once, uncomment below and run it the first time you run this notebook in a session).
# !pip install geemap
import geemap
